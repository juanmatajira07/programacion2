# %%
class vectoresR7:
    def __init__(self,L):
        self.L=L
    def __add__(self,v1):
        L=[self.L[i]+v1.L[i] for i in range (7)]
        return vectoresR7(L)
    def __repr__(self):
        return repr(self.L)

# %%
V,V2=[1,2,3,4,5,6,7],[1,1,1,1,1,1,1]
V,V2,V+V2
# Out:
# ([1, 2, 3, 4, 5, 6, 7],
#  [1, 1, 1, 1, 1, 1, 1],
#  [1, 2, 3, 4, 5, 6, 7, 1, 1, 1, 1, 1, 1, 1])

# %%
#n1=10.000 n2=20.000 n3=50.000
class cajero:
    def __init__(self,n1,n2,n3):
        self.n1=n1
        self.n2=n2*2
        self.n3=n3*5
    def retirar(self,cantidad):
        if cantidad%10000 != 0:
            return 'ingrese un multiplo de 10000'
        B10=cantidad//100000
        total=self.n1+self.n2+self.n3
        if cantidad<=total:
            if cantidad>=50:
        

            self.n3-=B10
        return f'le devuelvo {B10} billetes de '
retiro=cajero(10,10,10)
retiro.retirar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      12         return f'le devuelvo {B10} billetes de '
#      13 retiro=cajero(10,10,10)
# ---> 14 retiro.retirar()
#
# TypeError: cajero.retirar() missing 1 required positional argument: 'cantidad'
